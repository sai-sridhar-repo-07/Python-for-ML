# %%
import pandas as pd
import numpy as np

# %%
# Series - 1d array like object

data = [1,2,3,4,5]
series = pd.Series(data)
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(type(series))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data = {"a":1,"b":2,"c":3}
series = pd.Series(data)
print(series)
print(type(series))
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
data =[10,2,3,4,5]
indexes = ["a","b","c","d","e"]

pd.Series(data, index=indexes)
# Out:
# a    10
# b     2
# c     3
# d     4
# e     5
# dtype: int64

# %%
# Dataframe - 2d data 

data = {
    "Name": ["Hey","you","there"],
    "Age":[34,43,23],
    "City": ["Otto","Twills","Crimsone"]
}


df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age      City
# 0    Hey   34      Otto
# 1    you   43    Twills
# 2  there   23  Crimsone
# <class 'pandas.core.frame.DataFrame'>

# %%
np.array(df)
# Out:
# array([['Hey', 34, 'Otto'],
#        ['you', 43, 'Twills'],
#        ['there', 23, 'Crimsone']], dtype=object)

# %%
df.head(2)
# Out:
#   Name  Age    City
# 0  Hey   34    Otto
# 1  you   43  Twills

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc[1]
# Out:
# Name       you
# Age         43
# City    Twills
# Name: 1, dtype: object

# %%
df.iloc[2]
# Out:
# Name       there
# Age           23
# City    Crimsone
# Name: 2, dtype: object

# %%
df.at[1,'Age']
# Out:
# np.int64(43)

# %%
df.iat[2,2]
# Out:
# 'Crimsone'

# %%
df['Salary'] = [3000,4000,444444]

# %%
df.head()
# Out:
#     Name  Age      City  Salary
# 0    Hey   34      Otto    3000
# 1    you   43    Twills    4000
# 2  there   23  Crimsone  444444

# %%
df.drop('Salary',axis=1, inplace=True)

# %%
df
# Out:
#     Name  Age      City
# 0    Hey   34      Otto
# 1    you   43    Twills
# 2  there   23  Crimsone

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   33.333333
# std    10.016653
# min    23.000000
# 25%    28.500000
# 50%    34.000000
# 75%    38.500000
# max    43.000000

# %%
grouped = df.groupby('Name')['Age'].mean()
grouped
# Out:
# Name
# Hey      34.0
# there    23.0
# you      43.0
# Name: Age, dtype: float64
